                "https://www.imdb.com/title/tt8595010/?ref_=ttep_ep6",
                "https://www.imdb.com/title/tt8634664/?ref_=ttep_ep7",
                "https://www.imdb.com/title/tt9149072/?ref_=ttep_ep1",
                "https://www.imdb.com/title/tt9149082/?ref_=ttep_ep2",
                "https://www.imdb.com/title/tt9153740/?ref_=ttep_ep3",
                "https://www.imdb.com/title/tt9153742/?ref_=ttep_ep4",
                "https://www.imdb.com/title/tt9153746/?ref_=ttep_ep5",
                "https://www.imdb.com/title/tt9153744/?ref_=ttep_ep6",
                "https://www.imdb.com/title/tt9153748/?ref_=ttep_ep7",
                "https://www.imdb.com/title/tt9153750/?ref_=ttep_ep8",
                "https://www.imdb.com/title/tt9153752/?ref_=ttep_ep9",
                "https://www.imdb.com/title/tt9153754/?ref_=ttep_ep10",
                "https://www.imdb.com/title/tt9153756/?ref_=ttep_ep11",
                "https://www.imdb.com/title/tt9153758/?ref_=ttep_ep12",
                "https://www.imdb.com/title/tt9153762/?ref_=ttep_ep13",
                "https://www.imdb.com/title/tt9826592/?ref_=ttep_ep14",
                "https://www.imdb.com/title/tt9826594/?ref_=ttep_ep15",
                "https://www.imdb.com/title/tt9459092/?ref_=ttep_ep1",
                "https://www.imdb.com/title/tt9578274/?ref_=ttep_ep2",
                "https://www.imdb.com/title/tt9578286/?ref_=ttep_ep3",
                "https://www.imdb.com/title/tt9578284/?ref_=ttep_ep4",
                "https://www.imdb.com/title/tt10009394/?ref_=ttep_ep5",
                "https://www.imdb.com/title/tt10009392/?ref_=ttep_ep6",
                "https://www.imdb.com/title/tt10009404/?ref_=ttep_ep7",
                "https://www.imdb.com/title/tt10009408/?ref_=ttep_ep8",
                "https://www.imdb.com/title/tt10091760/?ref_=ttep_ep9",
                "https://www.imdb.com/title/tt10091764/?ref_=ttep_ep10",
                "https://www.imdb.com/title/tt10091770/?ref_=ttep_ep11",
                "https://www.imdb.com/title/tt10195344/?ref_=ttep_ep12",
                "https://www.imdb.com/title/tt10195346/?ref_=ttep_ep13",
                "https://www.imdb.com/title/tt10195350/?ref_=ttep_ep14",
                "https://www.imdb.com/title/tt10195352/?ref_=ttep_ep15",
                "https://www.imdb.com/title/tt10274688/?ref_=ttep_ep16",
                "https://www.imdb.com/title/tt10274696/?ref_=ttep_ep17",
                "https://www.imdb.com/title/tt10330426/?ref_=ttep_ep18",
                "https://www.imdb.com/title/tt10330430/?ref_=ttep_ep19",
                "https://www.imdb.com/title/tt10330436/?ref_=ttep_ep20",
                "https://www.imdb.com/title/tt10330448/?ref_=ttep_ep21",
                "https://www.imdb.com/title/tt10330456/?ref_=ttep_ep22",
                "https://www.imdb.com/title/tt10330468/?ref_=ttep_ep23"]

for link in links_episodios: # Pega cada link da lista de links para fazer a requisição
    requisicao = requests.get(link)

    sopa = BeautifulSoup(requisicao.content, "html.parser") # Dados brutos da página inteira
    
    # Conjunto que acha o nome da série
    acha_nome = sopa.find("div", {"class": "titleParent"})
    nome_serie = acha_nome.find("a").text

    # Conjunto que acha a temporada e o número do episódio
    acha_temp_episodio = sopa.find("div", {"class": "bp_description"})
    temp_episodio = acha_temp_episodio.find("div", {"class": "bp_heading"}).text.strip() # Temporada e episódio dentro da mesma tag separados por |
    lista = temp_episodio.split(" | ") # Comando split e cria uma lista com os dois itens
    temporada = lista[0] # Primeiro item da lista corresponde à temporada
    episodio = lista[1] # Segundo item da lista corresponde ao episódio
    temporada = temporada.replace("Season ", "") # Limpa para deixar só o número
    episodio = episodio.replace("Episode", "") # Limpa para deixar só o número
    
    # Conjunto que acha o nome do episódio
    acha_nome_episodio = sopa.find("div", {"class": "title_wrapper"}) # Div com o nome do episódio
    nome_episodio = acha_nome_episodio.find("h1").text.strip() # Limpa só o nome do episódio

    # Conjunto que acha a avaliação do episódio
    avaliacao = sopa.find("div", {"class": "imdbRating"})
    nota = avaliacao.find("span", {"itemprop": "ratingValue"}).text.strip()
    votos = avaliacao.find("span", {"itemprop": "ratingCount"}).text.strip()
    votos = votos.replace(",", "") # Limpa para poder converter para inteiro
    
    dicionario = {"serie": nome_serie, "temporada": temporada, "episodio": episodio, "nome_episodio": nome_episodio, "nota": float(nota), "votos": int(votos)} # Monta o dicionário
    planilha.append(dicionario) # Adiciona planilha ao dicionário
    
print(planilha)
# Out:
# [{'serie': 'RuPaul e a Corrida das Loucas', 'temporada': '11', 'episodio': ' 1', 'nome_episodio': 'Whatcha Unpackin?', 'nota': 7.9, 'votos': 191}, {'serie': 'RuPaul e a Corrida das Loucas', 'temporada': '11', 'episodio': ' 2', 'nome_episodio': 'Good God Girl, Get Out', 'nota': 8.3, 'votos': 172}, {'serie': 'RuPaul e a Corrida das Loucas', 'temporada': '11', 'episodio': ' 3', 'nome_episodio': 'Diva Worship', 'nota': 8.1, 'votos': 166}, {'serie': 'RuPaul e a Corrida das Loucas', 'temporada': '11', 'episodio': ' 4', 'nome_episodio': 'Trump: The Rusical', 'nota': 7.6, 'votos': 159}, {'serie': 'RuPaul e a Corrida das Loucas', 'temporada': '11', 'episodio': ' 5', 'nome_episodio': 'Monster Ball', 'nota': 7.4, 'votos': 133}, {'serie': 'RuPaul e a Corrida das Loucas', 'temporada': '11', 'episodio': ' 6', 'nome_episodio': 'The Draglympics', 'nota': 6.5, 'votos': 166}, {'serie': 'RuPaul e a Corrida das Loucas', 'temporada': '11', 'episodio': ' 7', 'nome_episodio': 'From Farm to Runway', 'nota':
# ...

# %%
import pandas

df = pandas.DataFrame(planilha)
df.to_csv("reality-show-competicao.csv", sep = ";", encoding = "utf-8")
df.sort_values(by = "nota", ascending = False)
# Out:
#                             serie temporada episodio  \
# 85                      The Voice        16       23
# 7   RuPaul e a Corrida das Loucas        11        8
# 25         American Ninja Warrior        10        0
# 13  RuPaul e a Corrida das Loucas        11       14
# 1   RuPaul e a Corrida das Loucas        11        2
# ..                            ...       ...      ...
# 47                     Mandou Bem         2        7
# 69                      The Voice        16        7
# 77                      The Voice        16       15
# 75                      The Voice        16       13
# 10  RuPaul e a Corrida das Loucas        11       11
#
#                             nome_episodio  nota  votos
# 85                    Live Finale Results   8.8     12
# 7                      Snatch Game at Sea   8.6    172
# 25  Red Nose Day: Celebrity Ninja Warrior   8.6     16
# 13                           Grand Finale   8.5    116
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

agrupamento1 = df.groupby("serie")["votos"].sum()
agrupamento1.plot.bar()

# %%
agrupamento2 = df.groupby("serie")["nota"].mean()
agrupamento2.plot.bar()
