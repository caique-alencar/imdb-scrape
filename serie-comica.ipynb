# %%
# Melhor Série Cômica

import requests
from bs4 import BeautifulSoup

planilha = []

links_episodios = ["https://www.imdb.com/title/tt8270790/?ref_=ttep_ep1",
                   "https://www.imdb.com/title/tt8884332/?ref_=ttep_ep2",
                   "https://www.imdb.com/title/tt8940996/?ref_=ttep_ep3",
                   "https://www.imdb.com/title/tt8956330/?ref_=ttep_ep4",
                   "https://www.imdb.com/title/tt8956336/?ref_=ttep_ep6",
                   "https://www.imdb.com/title/tt8956340/?ref_=ttep_ep7",
                   "https://www.imdb.com/title/tt8890392/?ref_=ttep_ep8",
                   "https://www.imdb.com/title/tt6733136/?ref_=ttep_ep1",
                   "https://www.imdb.com/title/tt9679520/?ref_=ttep_ep2",
                   "https://www.imdb.com/title/tt9679522/?ref_=ttep_ep3",
                   "https://www.imdb.com/title/tt9679524/?ref_=ttep_ep4",
                   "https://www.imdb.com/title/tt9679526/?ref_=ttep_ep5",
                   "https://www.imdb.com/title/tt6733140/?ref_=ttep_ep6",
                   "https://www.imdb.com/title/tt7664192/?ref_=ttep_ep1",
                   "https://www.imdb.com/title/tt8601200/?ref_=ttep_ep2",
                   "https://www.imdb.com/title/tt8601206/?ref_=ttep_ep3",
                   "https://www.imdb.com/title/tt8601210/?ref_=ttep_ep4",
                   "https://www.imdb.com/title/tt8534442/?ref_=ttep_ep5",
                   "https://www.imdb.com/title/tt8564998/?ref_=ttep_ep6",
                   "https://www.imdb.com/title/tt8488908/?ref_=ttep_ep7",
                   "https://www.imdb.com/title/tt8601212/?ref_=ttep_ep8",
                   "https://www.imdb.com/title/tt8578788/?ref_=ttep_ep9",
                   "https://www.imdb.com/title/tt8601222/?ref_=ttep_ep10",
                   "https://www.imdb.com/title/tt8601216/?ref_=ttep_ep11",
                   "https://www.imdb.com/title/tt7853310/?ref_=ttep_ep12",
                   "https://www.imdb.com/title/tt7667344/?ref_=ttep_ep1",
                   "https://www.imdb.com/title/tt7690008/?ref_=ttep_ep2",
                   "https://www.imdb.com/title/tt7772296/?ref_=ttep_ep3",
                   "https://www.imdb.com/title/tt7772302/?ref_=ttep_ep4",
                   "https://www.imdb.com/title/tt7775670/?ref_=ttep_ep5",
                   "https://www.imdb.com/title/tt7775674/?ref_=ttep_ep6",
                   "https://www.imdb.com/title/tt7775676/?ref_=ttep_ep7",
                   "https://www.imdb.com/title/tt7667348/?ref_=ttep_ep8",
                   "https://www.imdb.com/title/tt7978458/?ref_=ttep_ep9",
                   "https://www.imdb.com/title/tt7978462/?ref_=ttep_ep10",
                   "https://www.imdb.com/title/tt7526214/?ref_=ttep_ep1",
                   "https://www.imdb.com/title/tt8608804/?ref_=ttep_ep2",
                   "https://www.imdb.com/title/tt8709138/?ref_=ttep_ep3",
                   "https://www.imdb.com/title/tt8577836/?ref_=ttep_ep4",
                   "https://www.imdb.com/title/tt8526428/?ref_=ttep_ep5",
                   "https://www.imdb.com/title/tt8608802/?ref_=ttep_ep6",
                   "https://www.imdb.com/title/tt8709140/?ref_=ttep_ep7",
                   "https://www.imdb.com/title/tt8566574/?ref_=ttep_ep8",
                   "https://www.imdb.com/title/tt6932620/?ref_=ttep_ep1",
                   "https://www.imdb.com/title/tt7806352/?ref_=ttep_ep2",
                   "https://www.imdb.com/title/tt7870754/?ref_=ttep_ep3",
                   "https://www.imdb.com/title/tt7870756/?ref_=ttep_ep4",
                   "https://www.imdb.com/title/tt7870758/?ref_=ttep_ep5",
                   "https://www.imdb.com/title/tt7870760/?ref_=ttep_ep6",
                   "https://www.imdb.com/title/tt7870762/?ref_=ttep_ep7",
                   "https://www.imdb.com/title/tt9203528/?ref_=ttep_ep1",
                   "https://www.imdb.com/title/tt9525916/?ref_=ttep_ep2",
                   "https://www.imdb.com/title/tt9599994/?ref_=ttep_ep3",
                   "https://www.imdb.com/title/tt9639696/?ref_=ttep_ep4",
                   "https://www.imdb.com/title/tt9663044/?ref_=ttep_ep5",
                   "https://www.imdb.com/title/tt9728350/?ref_=ttep_ep6",
                   "https://www.imdb.com/title/tt9765702/?ref_=ttep_ep7",
                   "https://www.imdb.com/title/tt9799628/?ref_=ttep_ep8",
                   "https://www.imdb.com/title/tt9809498/?ref_=ttep_ep9",
                   "https://www.imdb.com/title/tt9809502/?ref_=ttep_ep10",
                   "https://www.imdb.com/title/tt9809506/?ref_=ttep_ep11",
                   "https://www.imdb.com/title/tt9870384/?ref_=ttep_ep12",
                   "https://www.imdb.com/title/tt9870386/?ref_=ttep_ep13",
                   "https://www.imdb.com/title/tt10005284/?ref_=ttep_ep14"]

for link in links_episodios: # Pega cada link da lista de links para fazer a requisição
    requisicao = requests.get(link)

    sopa = BeautifulSoup(requisicao.content, "html.parser") # Dados brutos da página inteira
    
    # Conjunto que acha o nome da série
    acha_nome = sopa.find("div", {"class": "titleParent"})
    nome_serie = acha_nome.find("a").text

    # Conjunto que acha a temporada e o número do episódio
    acha_temp_episodio = sopa.find("div", {"class": "bp_description"})
    temp_episodio = acha_temp_episodio.find("div", {"class": "bp_heading"}).text.strip() # Temporada e episódio dentro da mesma tag separados por |
    lista = temp_episodio.split(" | ") # Comando split e cria uma lista com os dois itens
    temporada = lista[0] # Primeiro item da lista corresponde à temporada
    episodio = lista[1] # Segundo item da lista corresponde ao episódio
    temporada = temporada.replace("Season ", "") # Limpa para deixar só o número
    episodio = episodio.replace("Episode", "") # Limpa para deixar só o número
    
    # Conjunto que acha o nome do episódio
    acha_nome_episodio = sopa.find("div", {"class": "title_wrapper"}) # Div com o nome do episódio
    nome_episodio = acha_nome_episodio.find("h1").text.strip() # Limpa só o nome do episódio

    # Conjunto que acha a avaliação do episódio
    avaliacao = sopa.find("div", {"class": "imdbRating"})
    nota = avaliacao.find("span", {"itemprop": "ratingValue"}).text.strip()
    votos = avaliacao.find("span", {"itemprop": "ratingCount"}).text.strip()
    votos = votos.replace(",", "") # Limpa para poder converter para inteiro
    
    dicionario = {"serie": nome_serie, "temporada": temporada, "episodio": episodio, "nome_episodio": nome_episodio, "nota": float(nota), "votos": int(votos)} # Monta o dicionário
    planilha.append(dicionario) # Adiciona planilha ao dicionário
    
print(planilha)
# Out:
# [{'serie': 'Barry', 'temporada': '2', 'episodio': ' 1', 'nome_episodio': 'The Show Must Go On, Probably?', 'nota': 8.5, 'votos': 1140}, {'serie': 'Barry', 'temporada': '2', 'episodio': ' 2', 'nome_episodio': 'The Power of No', 'nota': 8.1, 'votos': 1026}, {'serie': 'Barry', 'temporada': '2', 'episodio': ' 3', 'nome_episodio': 'Past = Present x Future Over Yesterday', 'nota': 8.6, 'votos': 1070}, {'serie': 'Barry', 'temporada': '2', 'episodio': ' 4', 'nome_episodio': 'What?!', 'nota': 9.2, 'votos': 1308}, {'serie': 'Barry', 'temporada': '2', 'episodio': ' 6', 'nome_episodio': 'The Truth Has a Ring to It', 'nota': 8.6, 'votos': 981}, {'serie': 'Barry', 'temporada': '2', 'episodio': ' 7', 'nome_episodio': 'The Audition', 'nota': 9.2, 'votos': 1170}, {'serie': 'Barry', 'temporada': '2', 'episodio': ' 8', 'nome_episodio': 'berkman > block', 'nota': 9.3, 'votos': 1311}, {'serie': 'Fleabag', 'temporada': '2', 'episodio': ' 1', 'nome_episodio': 'Episode #2.1', 'nota': 9.4, 'votos': 1353}, {'serie': 'Fleabag', 'temporada': '2', 'episodio': ' 2', 'nome_episodio': 'Episode #2.2', 'nota': 8.7, 'votos': 849}, {'serie': 'Fleabag', 'temporada': '2', 'episodio': ' 3', 'nome_episodio': 'Episode #2.3', 'nota': 9.1, 'votos': 889}, {'serie': 'Fleabag', 'temporada': '2', 'episodio': ' 4', 'nome_episodio': 'Episode #2.4', 'nota': 9.2, 'votos': 935}, {'serie': 'Fleabag', 'temporada': '2', 'episodio': ' 5', 'nome_episodio': 'Episode #2.5', 'nota': 9.0, 'votos': 830}, {'serie': 'Fleabag', 'temporada': '2', 'episodio': ' 6', 'nome_episodio': 'Episode #2.6', 'nota': 9.5, 'votos': 1126}, {'serie': 'O Bom Lugar', 'temporada': '3', 'episodio': ' 1', 'nome_episodio': 'Everything Is Bonzer!', 'nota': 8.4, 'votos': 1231}, {'serie': 'O Bom Lugar', 'temporada': '3', 'episodio': ' 2', 'nome_episodio': 'The Brainy Bunch', 'nota': 7.8, 'votos': 1047}, {'serie': 'O Bom Lugar', 'temporada': '3', 'episodio': ' 3', 'nome_episodio': 'The Snowplow', 'nota': 7.8, 'votos': 1018}, {'serie': 'O Bom Lugar', 'temporada': '3', 'episodio': ' 4', 'nome_episodio': 'Jeremy Bearimy', 'nota': 8.4, 'votos': 1089}, {'serie': 'O Bom Lugar', 'temporada': '3', 'episodio': ' 5', 'nome_episodio': 'The Ballad of Donkey Doug', 'nota': 7.6, 'votos': 983}, {'serie': 'O Bom Lugar', 'temporada': '3', 'episodio': ' 6', 'nome_episodio': 'A Fractured Inheritance', 'nota': 7.8, 'votos': 955}, {'serie': 'O Bom Lugar', 'temporada': '3', 'episodio': ' 7', 'nome_episodio': 'The Worst Possible Use of Free Will', 'nota': 8.2, 'votos': 905}, {'serie': 'O Bom Lugar', 'temporada': '3', 'episodio': ' 8', 'nome_episodio': "Don't Let the Good Life Pass You By", 'nota': 8.4, 'votos': 918}, {'serie': 'O Bom Lugar', 'temporada': '3', 'episodio': ' 9', 'nome_episodio': 'Janet(s)', 'nota': 9.2, 'votos': 1413}, {'serie': 'O Bom Lugar', 'temporada': '3', 'episodio': ' 10', 'nome_episodio': 'The Book of Dougs', 'nota': 8.1, 'votos': 820}, {'serie': 'O Bom Lugar', 'temporada': '3', 'episodio': ' 11', 'nome_episodio': 'Chidi Sees the Time-Knife', 'nota': 8.3, 'votos': 802}, {'serie': 'O Bom Lugar', 'temporada': '3', 'episodio': ' 12', 'nome_episodio': 'Pandemonium', 'nota': 8.6, 'votos': 960}, {'serie': 'Maravilhosa Sra. Maisel', 'temporada': '2', 'episodio': ' 1', 'nome_episodio': 'Simone', 'nota': 8.4, 'votos': 1040}, {'serie': 'Maravilhosa Sra. Maisel', 'temporada': '2', 'episodio': ' 2', 'nome_episodio': 'Mid-way to Mid-town', 'nota': 8.6, 'votos': 884}, {'serie': 'Maravilhosa Sra. Maisel', 'temporada': '2', 'episodio': ' 3', 'nome_episodio': 'The Punishment Room', 'nota': 8.3, 'votos': 821}, {'serie': 'Maravilhosa Sra. Maisel', 'temporada': '2', 'episodio': ' 4', 'nome_episodio': "We're Going to the Catskills!", 'nota': 8.6, 'votos': 902}, {'serie': 'Maravilhosa Sra. Maisel', 'temporada': '2', 'episodio': ' 5', 'nome_episodio': 'Midnight at the Concord', 'nota': 9.3, 'votos': 1047}, {'serie': 'Maravilhosa Sra. Maisel', 'temporada': '2', 'episodio': ' 6', 'nome_episodio': "Let's Face the Music and Dance", 'nota': 8.7 ...

# %%
import pandas

df = pandas.DataFrame(planilha)
df.to_csv("serie-comica.csv", sep = ";", encoding = "utf-8")
df.sort_values(by = "nota", ascending = False)
# Out:
#    episodio                        nome_episodio  nota  \
# 12        6                         Episode #2.6   9.5
# 49        7                                 Veep   9.5
# 7         1                         Episode #2.1   9.4
# 60       11                     Meet the Parents   9.4
# 29        5              Midnight at the Concord   9.3
# 62       13                             The Hike   9.3
# 63       14                    Life Is a Cabaret   9.3
# 6         8                      berkman > block   9.3
# 10        4                         Episode #2.4   9.2
# 5         7                         The Audition   9.2
# 33        9   Vote for Kennedy, Vote for Kennedy   9.2
# 21        9                             Janet(s)   9.2
# 3         4                               What?!   9.2
# 9         3                         Episode #2.3   9.1
# 11        5                         Episode #2.5   9.0
# 34       10                            All Alone   9.0
# 31        7                 Look, She Made a Hat   8.9
# 43        1                                 Iowa   8.8
# 30        6       Let's Face the Music and Dance   8.7
# 58        9                           The M.V.P.   8.7
# 48        6                                 Oslo   8.7
# 8         2                         Episode #2.2   8.7
# 28        4        We're Going to the Catskills!   8.6
# 50        1                        The Crowening   8.6
# 26        2                  Mid-way to Mid-town   8.6
# 54        5                         Housewarming   8.6
# 24       12                          Pandemonium   8.6
# 52        3                            The Plant   8.6
# 57        8                          The Hospies   8.6
# 61       12                            The Roast   8.6
# ..      ...                                  ...   ...
# 53        4                            The Dress   8.5
# 41        7                          The Way Out   8.5
# 55        6                             Rock On!   8.5
# 46        4                       South Carolina   8.5
# 45        3                               Pledge   8.5
# 0         1       The Show Must Go On, Probably?   8.5
# 32        8                           Someday...   8.4
# 13        1                Everything Is Bonzer!   8.4
# 16        4                       Jeremy Bearimy   8.4
# 56        7                  A Whisper of Desire   8.4
# 47        5                        Super Tuesday   8.4
# 20        8  Don't Let the Good Life Pass You By   8.4
# 25        1                               Simone   8.4
# 23       11            Chidi Sees the Time-Knife   8.3
# 44        2                    Discovery Weekend   8.3
# 27        3                  The Punishment Room   8.3
# 19        7  The Worst Possible Use of Free Will   8.2
# 40        6                           Reflection   8.2
# 1         2                      The Power of No   8.1
# 59       10                             Roadkill   8.1
# 22       10                    The Book of Dougs   8.1
# 39        5                  Superiority Complex   7.9
# 38        4                       Alan's Routine   7.9
# 18        6              A Fractured Inheritance   7.8
# 15        3                         The Snowplow   7.8
# 14        2                     The Brainy Bunch   7.8
# 17        5            The Ballad of Donkey Doug   7.6
# 37        3                          A Warm Body   7.6
# 36        2                     The Great Escape   7.5
# 35        1        Nothing in This World Is Easy   7.2
#
#                       serie temporada  votos
# 12                  Fleabag         2   1126
# 49                     Vice         7   1108
# 7                   Fleabag         2   1353
# 60           Schitt's Creek         5    219
# 29  Maravilhosa Sra. Maisel         2   1047
# 62           Schitt's Creek         5    170
# 63           Schitt's Creek         5    142
# 6                     Barry         2   1311
# 10                  Fleabag         2    935
# 5                     Barry         2   1170
# 33  Maravilhosa Sra. Maisel         2    873
# 21              O Bom Lugar         3   1413
# 3                     Barry         2   1308
# 9                   Fleabag         2    889
# 11                  Fleabag         2    830
# 34  Maravilhosa Sra. Maisel         2    878
# 31  Maravilhosa Sra. Maisel         2    842
# 43                     Vice         7    586
# 30  Maravilhosa Sra. Maisel         2    780
# 58           Schitt's Creek         5    112
# 48                     Vice         7    429
# 8                   Fleabag         2    849
# 28  Maravilhosa Sra. Maisel         2    902
# 50           Schitt's Creek         5    177
# 26  Maravilhosa Sra. Maisel         2    884
# 54           Schitt's Creek         5    144
# 24              O Bom Lugar         3    960
# 52           Schitt's Creek         5    132
# 57           Schitt's Creek         5    117
# 61           Schitt's Creek         5    102
# ..                      ...       ...    ...
# 53           Schitt's Creek         5    113
# 41             Boneca Russa         1   1223
# 55           Schitt's Creek         5    117
# 46                     Vice         7    429
# 45                     Vice         7    434
# 0                     Barry         2   1140
# 32  Maravilhosa Sra. Maisel         2    714
# 13              O Bom Lugar         3   1231
# 16              O Bom Lugar         3   1089
# 56           Schitt's Creek         5    115
# 47                     Vice         7    415
# 20              O Bom Lugar         3    918
# 25  Maravilhosa Sra. Maisel         2   1040
# 23              O Bom Lugar         3    802
# 44                     Vice         7    466
# 27  Maravilhosa Sra. Maisel         2    821
# 19              O Bom Lugar         3    905
# 40             Boneca Russa         1   1175
# 1                     Barry         2   1026
# 59           Schitt's Creek         5    108
# 22              O Bom Lugar         3    820
# 39             Boneca Russa         1   1177
# 38             Boneca Russa         1   1251
# 18              O Bom Lugar         3    955
# 15              O Bom Lugar         3   1018
# 14              O Bom Lugar         3   1047
# 17              O Bom Lugar         3    983
# 37             Boneca Russa         1   1281
# 36             Boneca Russa         1   1390
# 35             Boneca Russa         1   1645
#
# [64 rows x 6 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

agrupamento1 = df.groupby("serie")["nota"].mean()
agrupamento1.plot.bar()

# %%
agrupamento2 = df.groupby("serie")["votos"].sum()
agrupamento2.plot.bar()
